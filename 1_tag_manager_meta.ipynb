# %%
import pandas as pd
import spacy
import re

spacy.prefer_gpu()
nlp = spacy.load('es_core_news_md')

# %%
df = pd.read_csv('C:/Users/qsavy_1/CCD/ccd_meta/video_data_final.csv')
df = df[['tags', 'viewCount', 'publishedAt']]
df
# Out:
#                                                    tags  viewCount  \
# 0                                            ['roblox']   819935.0
# 1                                         ['minecraft']  3900502.0
# 2                                         ['escondite']  2827316.0
# 3                                            ['roblox']  2692418.0
# 4                                         ['minecraft']  4171162.0
# ...                                                 ...        ...
# 2378                                                NaN   109804.0
# 2379  ['german garmendia', 'musica', 'pop', 'pop hit...  2040533.0
# 2380  ['german garmendia', 'musica', 'canciones', 'p...  5487331.0
# 2381  ['german garmendia', 'german', 'garmendia', 'm...  6483164.0
# 2382  ['GermanGarmendia', 'Supernova', 'music', 'mus...  7484029.0
#
#                publishedAt
# 0     2022-07-28T18:15:03Z
# 1     2022-06-18T20:45:18Z
# 2     2022-06-10T18:54:53Z
# 3     2022-06-04T18:20:42Z
# ...

# %%
tag_class = df['tags'].astype (str)
tag_list = tag_class.values.tolist()
all_words_str = ''.join(tag_list)
all_words_str
# Out:
# '[\'roblox\'][\'minecraft\'][\'escondite\'][\'roblox\'][\'minecraft\'][\'escondite\'][\'los compas\', \'eltrollino\', \'mikecrack\'][\'minecraft\'][\'gta 5\'][\'roblox\'][\'minecraft\'][\'minecraft\'][\'roblox\'][\'roblox\'][\'roblox\'][\'pk xd\', \'minecraft\', \'eltrollino\', \'mikecrack\'][\'roblox\', \'roblox tycoon\', \'super hero tycoon roblox\', \'spiderman\']nan[\'minecraft\'][\'poppy\', \'poppy playtime\'][\'minecraft\'][\'el juego del calamar\'][\'minecraft\'][\'gta 5\'][\'minecraft\', \'pk xd\', \'eltrollino\', \'trollino\', \'mikecrack\', \'acenix\'][\'gta 5\', \'gta v\', \'gta 5 online\', \'eltrollino\', \'mikecrack\', \'carrera\', \'gta 5 carrera\'][\'Si o no\', \'Reto\', \'Challenge\', \'shorts\', \'#shorts\'][\'gta 5\', \'castillo vs castillo\'][\'gta 5\', \'gta 5 online\', \'carrera\', \'eltrollino\', \'trollino\', \'los compas\', \'gta 5 los compas\'][\'roblox\'][\'minecraft\'][\'minecraft\', \'los compas\', \'pk xd\', \'eltrollino\', \'trollino\'][\'minecraft\', \'
# ...

# %%
doc = nlp(all_words_str)

doc = [token for token in doc if not token.is_punct]
' '.join(token.text for token in doc)
# Out:
# 'roblox\'][\'minecraft\'][\'escondite\'][\'roblox\'][\'minecraft\'][\'escondite\'][\'los compas eltrollino mikecrack\'][\'minecraft\'][\'gta 5\'][\'roblox\'][\'minecraft\'][\'minecraft\'][\'roblox\'][\'roblox\'][\'roblox\'][\'pk xd minecraft eltrollino mikecrack\'][\'roblox roblox tycoon super hero tycoon roblox spiderman\']nan[\'minecraft\'][\'poppy poppy playtime\'][\'minecraft\'][\'el juego del calamar\'][\'minecraft\'][\'gta 5\'][\'minecraft pk xd eltrollino trollino mikecrack acenix\'][\'gta 5 gta v gta 5 online eltrollino mikecrack carrera gta 5 carrera\'][\'Si o no Reto Challenge shorts shorts\'][\'gta 5 castillo vs castillo\'][\'gta 5 gta 5 online carrera eltrollino trollino los compas gta 5 los compas\'][\'roblox\'][\'minecraft\'][\'minecraft los compas pk xd eltrollino trollino\'][\'minecraft chicos vs chicas\'][\'genshin impact eltrollino los compas trollino portal secreto dimension genshin impact gameplay\'][\'minecraft\'][\'animacion los compas eltrollino mikecrack siren
# ...

# %%
doc3 = re.sub(pattern = '[...]',
repl = "",
string = all_words_str)

# %%
# boundery detection:


from spacy.matcher import Matcher

nlp1 = spacy.load('es_core_news_md')


matcher = Matcher(nlp.vocab)
pattern = [
          {'ORTH': "'"},
          {'POS':'PROPN', 'OP':'+'},
          {'ORTH': "'"},
          ] 
matcher.add('PEOPER_NOUNS', [pattern], greedy='LONGEST')
doc1 = nlp1(doc3)
matches = matcher(doc1)
matches.sort(key = lambda x: x[1])
print(len(matches))
for match in matches[:200]:
    print(match, doc1[match[1]:match[2]])
# Out:
# 8022
# (18135987400277701921, 53, 57) 'pk xd'
# (18135987400277701921, 66, 69) 'mikecrack'
# (18135987400277701921, 90, 93) 'mikecrack'
# (18135987400277701921, 106, 109) 'Reto'
# (18135987400277701921, 110, 113) 'Challenge'
# (18135987400277701921, 166, 170) 'pk xd'
# (18135987400277701921, 223, 226) 'mikecrack'
# (18135987400277701921, 256, 259) 'mikecrack'
# (18135987400277701921, 269, 272) 'mikecrack'
# (18135987400277701921, 1839, 1843) 'jason voorhees'
# (18135987400277701921, 1844, 1847) 'jason'
# (18135987400277701921, 3092, 3095) 'egipto'
# (18135987400277701921, 3419, 3422) 'Tinder'
# (18135987400277701921, 5135, 5139) 'jojo siwa'
# (18135987400277701921, 5154, 5158) 'lil pump'
# (18135987400277701921, 5159, 5162) 'benjaminkicks'
# (18135987400277701921, 5170, 5173) 'youtube'
# (18135987400277701921, 5391, 5395) 'google maps'
# (18135987400277701921, 6526, 6530) 'DOC TOPS'
# (18135987400277701921, 6956, 6960) 'Luan Palomera'
# ...

# %%
for match_id, start, end in matches:
    print(doc1[start:end])
# Out:
# 'pk xd'
# 'mikecrack'
# 'mikecrack'
# 'Reto'
# 'Challenge'
# 'pk xd'
# 'mikecrack'
# 'mikecrack'
# 'mikecrack'
# 'jason voorhees'
# 'jason'
# 'egipto'
# 'Tinder'
# 'jojo siwa'
# 'lil pump'
# 'benjaminkicks'
# 'youtube'
# 'google maps'
# 'DOC TOPS'
# 'Luan Palomera'
# 'Luan Palomera'
# 'mickey'
# 'Star Wars'
# 'rico'
# 'Cheetos'
# 'McDonalds'
# 'Doritos'
# 'pixar'
# 'pixar'
# 'rey leon'
# 'Easter eggs'
# 'pixar'
# 'Spiderman'
# 'venom'
# 'Luca'
# 'Luan Palomera'
# 'Netflix'
# 'Luca'
# 'pixar'
# 'rey leon'
# 'pixar'
# 'Mario'
# 'Zelda'
# 'Luan Palomera'
# 'Spiderman'
# 'Luca'
# 'pixar'
# 'rey leon'
# 'rico'
# 'Cheetos'
# 'McDonalds'
# 'Luan Palomera'
# 'Luan Palomera'
# 'Luca'
# 'mickey'
# 'Star Wars'
# 'Luan Palomera'
# 'Easter eggs'
# 'Luan Palomera'
# 'Luca'
# 'pixar'
# 'Easter eggs'
# 'Luan Palomera'
# 'Luca'
# 'pixar'
# 'Luan Palomera'
# 'Luca'
# 'pixar'
# 'Zelda'
# 'Mario'
# 'Luan Palomera'
# 'Luca'
# 'Spiderman'
# 'Luca'
# 'Mario'
# 'rico'
# 'Cheetos'
# 'Luca'
# 'McDonalds'
# ...

# %%
print(len(out))
# Out:
# 8058

# %% [markdown]
# # Pattern Recognizer:

# %%
# toponimos :
# regex : regular expresions:

# %%
# buscar tags particulares y vectorizar similares

from spacy.tokens import Span

nlp2 = spacy.blank('en')
doc2 = nlp2(doc1)

pattern = r'fantasmas [a-z]\w+'

for match in matches:
    original_ents = list(doc2.ents)
    tag_ents =[]
for match in re.finditer(pattern, doc2.text):
    start, end = match.span()
    span = doc2.char_span(start, end)

    if span is not None:
        tag_ents.append((span.start, span.end, span.text))

# %%
print(span)
# Out:
# fantasmas gritar

# %%
# entity injector:
for ent in tag_ents:
    start, end, name = ent
    per_ent = Span(doc2, start, end, label='') # assign label
    original_ents.append(per_ent)
doc2.ents = original_ents
for ent in doc2.ents:
    print(ent.text, ent.label_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       3     start, end, name = ent
#       4     per_ent = Span(doc2, start, end, label='') # assign label
# ----> 5     original_entr.append(per_ent)
#       6 doc2.ents = original_ents
#       7 for ent in doc2.ents:
#
# NameError: name 'original_entr' is not defined

# %%
from spacy.lenguage import Lenguage
@Lenguage.component('luisito')
def luisito(doc2):
    original_ents = list(doc2.ents)
    tag_ents =[]
for match in re.finditer(pattern, doc2.text):
    start, end = match.span()
    span = doc2.char_span(start, end)

    if span is not None:
        tag_ents.append((span.start, span.end, span.text))

for ent in tag_ents:
    start, end, name = ent
    per_ent = Span(doc2, start, end, label='youtuber') # assign label
    original_entr.append(per_ent)
doc2.ents = original_ents
return(doc2)
